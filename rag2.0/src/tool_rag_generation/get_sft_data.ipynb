# %%
import sys 
import re
import os
import ast
import pandas as pd
from data_format import DataFormat,gen_multi_sft_data
sys.path.append("../..") 
from common import utils_log,utils
from convert_to_train_data import load_data,check_illegal_data

# %%
def safe_eval(x):
    try:
        return ast.literal_eval(x) if isinstance(x, str) else x
    except (ValueError, SyntaxError):
        return ""

# %%
input_load_folder = '/mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/csv/v20240827_new/'
output_load_folder = '/mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/jsonl/v20240827_new/'
output_paths = [output_load_folder + 'charYou-single-1422.jsonl']
df = pd.read_excel(input_load_folder+'人设合并送标数据.xlsx')
df = df.drop(columns=['query_has_time', 'assistant_has_time',
       'query_has_you', 'query_has_command', 'user', 'assistant',
       'source_file', 'owner', 'folder', 'dataset', 'uuid', 'vertify_messages','reason'])
df['messages'] = df['messages'].apply(safe_eval)
df = df[df['messages']!='']
df.to_json(output_paths[i], orient='records', lines=True, force_ascii=False)

# %%
input_load_folder = '/mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/csv/v20240827_new/'
output_load_folder = '/mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/jsonl/v20240827_new/'
input_paths = [input_load_folder+'人设合并送标数据.csv']
utils.create_directory(output_load_folder)
output_paths = [output_load_folder + 'charYou-single.jsonl']

dataformat_obj = DataFormat(api_flag=True,multi_flag=False)
for i in range(len(input_paths)):
    print(input_paths[i])
    df = utils.preprocess_df(input_paths[i])
    sft_df = dataformat_obj.gen_sft_data(df)
    sft_df.to_json(output_paths[i], orient='records', lines=True, force_ascii=False)

# %%
# date_folder = 'v20240607/'
input_load_folder = '/workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/'
output_load_folder = '/workspace/renhuimin/pro_rag/data/train_data/jsonl/verified/renhuimin_assistant_sft/'

# %%
# 通用问答
input_paths = [input_load_folder+'general/通用问答语料库 - 人设.csv',
               input_load_folder+'general/通用问答语料库 - 人物百科.csv',
               input_load_folder+'general/通用问答语料库 - 诗词歌词.csv',
               input_load_folder+'general/通用问答语料库 - 通用问答卡片.csv',
               input_load_folder+'general/通用问答语料库 - 通用问答相关非卡片-数字专项.csv',
               input_load_folder+'general/通用问答语料库 - 通用问答相关非卡片.csv',
               input_load_folder+'general/通用问答语料库 - 为什么不.csv',
               input_load_folder+'general/通用问答语料库 - 线上日志.csv',
               input_load_folder+'general/通用问答语料库 - 影视百科.csv',
               input_load_folder+'general/通用问答语料库 - obs时间理解.csv',
               input_load_folder+'general/通用问答语料库 - obs一词多义.csv',
               input_load_folder+'general/通用问答语料库 - P0123.csv',
               input_load_folder+'general/通用问答语料库 - RAG知乎.csv']

utils.create_directory(output_load_folder + 'general/')
output_paths = [output_load_folder+'general/character-single.jsonl',
                output_load_folder+'general/baikePPl-single.jsonl',
                output_load_folder+'general/poem-single.jsonl',
                output_load_folder+'general/brCard-single.jsonl',
                output_load_folder+'general/digits-single.jsonl',
                output_load_folder+'general/general-single.jsonl',
                output_load_folder+'general/whynot-single.jsonl',
                output_load_folder+'general/onlineLog-single.jsonl',
                output_load_folder+'general/baikeMovie-single.jsonl',
                output_load_folder+'general/obsTime-single.jsonl',
                output_load_folder+'general/obsQiyi-single.jsonl',
                output_load_folder+'general/p0123-single.jsonl',
                output_load_folder+'general/zhihu-single.jsonl']

dataformat_obj = DataFormat(api_flag=True,multi_flag=False)

for i in range(len(input_paths)):
    print(input_paths[i])
    df = utils.preprocess_df(input_paths[i])
    sft_df = dataformat_obj.gen_sft_data(df)
    sft_df.to_json(output_paths[i], orient='records', lines=True, force_ascii=False)

gen_multi_sft_data(output_load_folder,output_paths,category='general',output_num=0.5)
# Out:
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/general/通用问答语料库 - 人设.csv
# sft 数量： 143
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/general/通用问答语料库 - 人物百科.csv
# sft 数量： 2588
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/general/通用问答语料库 - 诗词歌词.csv
# sft 数量： 467
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/general/通用问答语料库 - 通用问答卡片.csv
# sft 数量： 710
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/general/通用问答语料库 - 通用问答相关非卡片-数字专项.csv
# sft 数量： 4843
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/general/通用问答语料库 - 通用问答相关非卡片.csv
# sft 数量： 7757
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/general/通用问答语料库 - 为什么不.csv
# sft 数量： 59
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/general/通用问答语料库 - 线上日志.csv
# sft 数量： 3650
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/general/通用问答语料库 - 影视百科.csv
# ...

# %%
input_paths = [input_load_folder+'entertainment/娱乐助手语料库 - 体育.csv',
               input_load_folder+'entertainment/娱乐助手语料库 - 新闻.csv',
               input_load_folder+'entertainment/娱乐助手语料库 - 音乐.csv',
               input_load_folder+'entertainment/娱乐助手语料库 - 影视.csv']

utils.create_directory(output_load_folder + 'entertainment/')
output_paths = [output_load_folder+'entertainment/sports-single.jsonl',
                output_load_folder+'entertainment/news-single.jsonl',
                output_load_folder+'entertainment/music-single.jsonl',
                output_load_folder+'entertainment/movie-single.jsonl']


dataformat_obj = DataFormat(api_flag=True,multi_flag=False)
for i in range(len(input_paths)):
    print(input_paths[i])
    df = utils.preprocess_df(input_paths[i])
    sft_df = dataformat_obj.gen_sft_data(df)
    sft_df.to_json(output_paths[i], orient='records', lines=True, force_ascii=False)

gen_multi_sft_data(output_load_folder,output_paths,category='entertainment',output_num=0.5) 

input_path = input_load_folder+'entertainment/娱乐助手语料库 - 多轮.csv'
output_path = output_load_folder+'entertainment/sports_multi.jsonl'
dataformat_obj = DataFormat(api_flag=True,multi_flag=True)
print(input_path)
df = utils.preprocess_df(input_path)
sft_df = dataformat_obj.gen_sft_data(df)
sft_df.to_json(output_path, orient='records', lines=True, force_ascii=False)
# Out:
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/entertainment/娱乐助手语料库 - 体育.csv
# sft 数量： 6581
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/entertainment/娱乐助手语料库 - 新闻.csv
# sft 数量： 371
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/entertainment/娱乐助手语料库 - 音乐.csv
# sft 数量： 1442
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/entertainment/娱乐助手语料库 - 影视.csv
# sft 数量： 2165
# ...
# 100%|██████████| 1082/1082 [00:00<00:00, 3021.56output/s]
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/entertainment/娱乐助手语料库 - 多轮.csv
# sft 数量： 714

# %%
input_paths = [input_load_folder+'car/汽车问答语料库 - 半相关.csv',
               input_load_folder+'car/汽车问答语料库 - 不相关.csv',
               input_load_folder+'car/汽车问答语料库 - 参数对比.csv',
               input_load_folder+'car/汽车问答语料库 - 充电桩.csv',
               input_load_folder+'car/汽车问答语料库 - 带prompt.csv',
               input_load_folder+'car/汽车问答语料库 - 服务专家.csv',
               input_load_folder+'car/汽车问答语料库 - 理想公司高管.csv',
               input_load_folder+'car/汽车问答语料库 - 汽车卡片.csv',
               input_load_folder+'car/汽车问答语料库 - 时效性.csv',
               input_load_folder+'car/汽车问答语料库 - 线上日志.csv',
               input_load_folder+'car/汽车问答语料库 - 整车对比.csv',
               input_load_folder+'car/汽车问答语料库 - br非总分.csv']

utils.create_directory(output_load_folder + 'car/')
output_paths = [output_load_folder+'car/half-single.jsonl',
                output_load_folder+'car/irrelevant-single.jsonl',
                output_load_folder+'car/paramComparison-single.jsonl',
                output_load_folder+'car/charge-single.jsonl',
                output_load_folder+'car/prompt-single.jsonl',
                output_load_folder+'car/service-single.jsonl',
                output_load_folder+'car/cxo-single.jsonl',
                output_load_folder+'car/brCard-single.jsonl',
                output_load_folder+'car/realtime-single.jsonl',
                output_load_folder+'car/CarOnlineLog-single.jsonl',
                output_load_folder+'car/wholeComparison-single.jsonl',
                output_load_folder+'car/nobr-single.jsonl']

dataformat_obj = DataFormat(api_flag=True,multi_flag=False)
for i in range(len(input_paths)):
    print(input_paths[i])
    df = utils.preprocess_df(input_paths[i])
    sft_df = dataformat_obj.gen_sft_data(df)
    sft_df.to_json(output_paths[i], orient='records', lines=True, force_ascii=False)

gen_multi_sft_data(output_load_folder,output_paths,category='car',output_num=0.5)
# Out:
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/car/汽车问答语料库 - 半相关.csv
# sft 数量： 232
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/car/汽车问答语料库 - 不相关.csv
# sft 数量： 107
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/car/汽车问答语料库 - 参数对比.csv
# sft 数量： 281
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/car/汽车问答语料库 - 充电桩.csv
# sft 数量： 204
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/car/汽车问答语料库 - 带prompt.csv
# sft 数量： 396
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/car/汽车问答语料库 - 服务专家.csv
# sft 数量： 3884
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/car/汽车问答语料库 - 理想公司高管.csv
# sft 数量： 97
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/car/汽车问答语料库 - 汽车卡片.csv
# sft 数量： 159
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/car/汽车问答语料库 - 时效性.csv
# sft 数量： 5
# ...

# %%
# 出游灵感
input_paths = [input_load_folder+'tourism/出游灵感语料库 - 出行规划.csv',
               input_load_folder+'tourism/出游灵感语料库 - 出游灵感.csv',
               input_load_folder+'tourism/出游灵感语料库 - 地理位置.csv',
               input_load_folder+'tourism/出游灵感语料库 - 线上日志.csv',
               input_load_folder+'tourism/出游灵感语料库 - 总分卡片.csv',
               input_load_folder+'tourism/出游灵感语料库 - br非总分.csv']

utils.create_directory(output_load_folder + 'tourism/')
output_paths = [output_load_folder+'tourism/planning-single.jsonl',
                output_load_folder+'tourism/tourism-single.jsonl',
                output_load_folder+'tourism/location-single.jsonl',
                output_load_folder+'tourism/onlineLog-single.jsonl',
                output_load_folder+'tourism/brCard-single.jsonl',
                output_load_folder+'tourism/nobr-single.jsonl']

dataformat_obj = DataFormat(api_flag=True,multi_flag=False)
for i in range(len(input_paths)):
    print(input_paths[i])
    df = utils.preprocess_df(input_paths[i])
    sft_df = dataformat_obj.gen_sft_data(df)
    sft_df.to_json(output_paths[i], orient='records', lines=True, force_ascii=False)

gen_multi_sft_data(output_load_folder,output_paths,category='tourism',output_num=0.5)
# Out:
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/tourism/出游灵感语料库 - 出行规划.csv
# sft 数量： 501
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/tourism/出游灵感语料库 - 出游灵感.csv
# sft 数量： 4357
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/tourism/出游灵感语料库 - 地理位置.csv
# sft 数量： 761
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/tourism/出游灵感语料库 - 线上日志.csv
# sft 数量： 742
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/tourism/出游灵感语料库 - 总分卡片.csv
# sft 数量： 989
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/business/tourism/出游灵感语料库 - br非总分.csv
# sft 数量： 249
# ...
# 100%|██████████| 124/124 [00:00<00:00, 3416.48output/s]

# %%
# RAG技能数据
input_load_folder = '/workspace/renhuimin/pro_rag/data/train_data/csv/verified/skills/'
output_load_folder = '/workspace/renhuimin/pro_rag/data/train_data/jsonl/verified/'
input_paths = [input_load_folder+f for f in os.listdir(input_load_folder) if 'norag' not in f and '.ipynb_checkpoints' not in f]
utils.create_directory(output_load_folder + 'skills/')
output_path = output_load_folder + 'skills/skills-single.jsonl'

dataformat_obj = DataFormat(api_flag=True,multi_flag=False)
dl = []
for i in range(len(input_paths)):
    print(input_paths[i])
    df = utils.preprocess_df(input_paths[i])
    sft_df = dataformat_obj.gen_sft_data(df)
    dl.append(sft_df)
sft_df = pd.concat(dl)
sft_df.to_json(output_path, orient='records', lines=True, force_ascii=False)


input_paths = [input_load_folder+f for f in os.listdir(input_load_folder) if 'norag' in f and '.ipynb_checkpoints' not in f]
output_path = output_load_folder + 'skills/noRAGobs-single.jsonl'

dataformat_obj = DataFormat(api_flag=False,multi_flag=False)
dl = []
for i in range(len(input_paths)):
    print(input_paths[i])
    df = utils.preprocess_df(input_paths[i])
    sft_df = dataformat_obj.gen_sft_data(df)
    dl.append(sft_df)
sft_df = pd.concat(dl)
sft_df.to_json(output_path, orient='records', lines=True, force_ascii=False)
# Out:
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/skills/训练集_norag_oneshot_obs相关性判断_923.csv
# sft 数量： 924
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/skills/训练集_norag_单条obs_obs相关性判断_1848.csv
# sft 数量： 1848
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/skills/训练集_norag_zeroshot_obs相关性判断_928.csv
# sft 数量： 927

# %%
input_load_folder = '/workspace/renhuimin/pro_rag/data/train_data/csv/verified/skills/'
output_load_folder = '/workspace/renhuimin/pro_rag/data/train_data/jsonl/verified/renhuimin_assistant_sft/'
input_paths = [input_load_folder+'训练集_指令遵循_markdown_468.csv',
               input_load_folder+'训练集_obs扩展不相关by0624_2k.csv']
utils.create_directory(output_load_folder + 'skills/')
output_paths = [output_load_folder + 'skills/obsFollowMD-single.jsonl',
                output_load_folder + 'skills/obsMoreIrre1-single.jsonl']

dataformat_obj = DataFormat(api_flag=True,multi_flag=False)
for i in range(len(input_paths)):
    print(input_paths[i])
    df = utils.preprocess_df(input_paths[i])
    sft_df = dataformat_obj.gen_sft_data(df)
    sft_df.to_json(output_paths[i], orient='records', lines=True, force_ascii=False)
# Out:
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/skills/训练集_指令遵循_markdown_456.csv
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:2 vs 1
# sft 数量： 468
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/skills/训练集_obs扩展不相关by0624_2k.csv
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:2 vs 1
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:1 vs 2
# API数量与OBS数量不对应:2 vs 1
# ...

# %%
input_load_folder = '/workspace/renhuimin/pro_rag/data/train_data/csv/verified/multi_turn/'
output_load_folder = '/workspace/renhuimin/pro_rag/data/train_data/jsonl/verified/renhuimin_assistant_sft/'

input_paths = [input_load_folder+'auto_multi_46k_0615.csv',
               input_load_folder+'human_multi_12kto6k.csv',
               input_load_folder+'human_multi_29kto10k.csv',
               input_load_folder+'human_multi_Feb1k.csv']

utils.create_directory(output_load_folder + 'multi_turn/')
output_paths = [output_load_folder+'multi_turn/auto_multi_46k_0615.jsonl',
                output_load_folder+'multi_turn/human_multi_12kto6k.jsonl',
                output_load_folder+'multi_turn/human_multi_29kto10k.jsonl',
                output_load_folder+'multi_turn/human_multi_Feb1k.jsonl']


dataformat_obj = DataFormat(api_flag=True,multi_flag=True)
for i in range(len(input_paths)):
    print(input_paths[i])
    df = utils.preprocess_df(input_paths[i])
    sft_df = dataformat_obj.gen_sft_data(df)
    sft_df.to_json(output_paths[i], orient='records', lines=True, force_ascii=False)
# Out:
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/multi_turn/human_multi_12kto6k.csv
# sft 数量： 6043
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/multi_turn/human_multi_29kto10k.csv
# sft 数量： 10974
# /workspace/renhuimin/pro_rag/data/train_data/csv/verified/multi_turn/human_multi_Feb1k.csv
# sft 数量： 1435

# %%
### 验证数据有效性
folder_path = "/mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/jsonl/0_train_data/2024-08-27/renhuimin_assistant_sft"
df = load_data(folder_path)
df = check_illegal_data(df)
# Out:
# /mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/jsonl/0_train_data/2024-08-27/renhuimin_assistant_sft/log_app/appLog_dpo_by0808_120.jsonl
# /mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/jsonl/0_train_data/2024-08-27/renhuimin_assistant_sft/log_app/appLog_by0804_700.jsonl
# /mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/jsonl/0_train_data/2024-08-27/renhuimin_assistant_sft/log_app/appTest_1k.jsonl
# /mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/jsonl/0_train_data/2024-08-27/renhuimin_assistant_sft/log_app/vip122.jsonl
# /mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/jsonl/0_train_data/2024-08-27/renhuimin_assistant_sft/log_app/appLog_by0804_1500.jsonl
# /mnt/pfs-guan-ssai/nlu/renhuimin/rag_tool/data/train_data/sft/jsonl/0_train_data/2024-08-27/renhuimin_assistant_sft/log_app/sft_by0807.jsonl
# ...

# %%
df.groupby('vertify_messages').count()
# Out:
#                                   id  turn_id  source  messages  \
# vertify_messages
# ###assistant不符公司安全及诗词脏数据!###       5        5       5         5
# ###assistant不符合翻译规则!###            1        1       1         1
# ###assistant人设不合法!###          39782    25757   39782     39782
# ###messages 格式不正确！###           3621        9    3621      3621
# ###user人设不合法!###                 199      198     199       199
# 合格                            220176   163468  220176    220176
#
#                               produce_source  create_time  update_time  \
# vertify_messages
# ###assistant不符公司安全及诗词脏数据!###               4            4            4
# ###assistant不符合翻译规则!###                    1            1            1
# ###assistant人设不合法!###                  39705        39705        39705
# ###messages 格式不正确！###                     36         3621         3621
# ###user人设不合法!###                         199          199          199
# ...

# %%
# folder = '/workspace/renhuimin/pro_qa/data/train_data/csv/multi_turn/'
# dfm = pd.read_csv(folder+'auto_multi_46k_0615.csv')
# dataformat_obj = DataFormat(api_flag=True,multi_flag=True)
# sft_df = dataformat_obj.gen_sft_data(dfm)
# output_path = "/workspace/renhuimin/pro_rag/data/train_data/jsonl/verified/renhuimin_assistant_sft/multi_turn/auto_multi_46k_0615.jsonl"
# sft_df.to_json(output_path, orient='records', lines=True, force_ascii=False)
# Out:
# /tmp/ipykernel_480379/3164535963.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfm = pd.read_csv(folder+'auto_multi_46k_0615.csv')
# sft 数量： 46940

# %%
# folder = '/workspace/nlu/lizr/wangheqing/raw_data/v20240628/origin_data/renhuimin_assistant_sft/multi_turn/'
# files = [f for f in os.listdir(folder)]
# dl = []
# for file in files:
#     print(file)
#     df = pd.read_json(folder+file,lines=True)
#     dl.append(df)

# df = pd.concat(dl)
# df

# file = '/workspace/renhuimin/pro_rag/data/train_data/jsonl/verified/renhuimin_assistant_sft/multi_turn/auto_multi_46k_0615.jsonl'
# df[['id', 'source', 'messages', 'system_prompt','create_user', 'update_user',
#     'create_time', 'update_time']].to_json(file, orient='records', lines=True, force_ascii=False)
